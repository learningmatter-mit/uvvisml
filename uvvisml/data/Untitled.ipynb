# %%
import pandas as pd
import os
import numpy as np
from rdkit.Chem import AllChem as Chem

# %%
same_test_set = 'true'
optical_properties = ['absPeak', 'emiPeak']

# %%
joung_df = pd.read_csv('original/joung/DB_for_chromophore_Sci_Data_rev02.csv')
joung_df
# Out:
#          Tag                                        Chromophore    Solvent  \
# 0          1                             N#Cc1cc2ccc(O)cc2oc1=O          O
# 1          2                          N#Cc1cc2ccc([O-])cc2oc1=O          O
# 2          3  CCCCCCCCCCCC#CC#CCCCCCCCCCN1C(=O)c2ccc3c4ccc5c...  ClC(Cl)Cl
# 3          4       [O-]c1c(-c2nc3ccccc3s2)cc2ccc3cccc4ccc1c2c34       CC#N
# 4          5       [O-]c1c(-c2nc3ccccc3s2)cc2ccc3cccc4ccc1c2c34    CS(C)=O
# ...      ...                                                ...        ...
# 20231  20232    N#Cc1c(N2CCCC2)cc(-c2ccccc2)c2c1C(=O)c1ccccc1-2    C1CCOC1
# 20232  20233   N#Cc1c(N2CCCCC2)cc(-c2ccccc2)c2c1C(=O)c1ccccc1-2    C1CCOC1
# 20233  20234  N#Cc1c(N2CCCCC2)cc(-c2cccc3ccccc23)c2c1C(=O)c1...    C1CCOC1
# 20234  20235  N#Cc1c(N2CCCCC2)cc(-c2ccc3ccccc3c2)c2c1C(=O)c1...    C1CCOC1
# 20235  20236  N#Cc1c(N2CCCCC2)cc(-c2ccc3ccc4cccc5ccc2c3c45)c...    C1CCOC1
#
#        Absorption max (nm)  Emission max (nm)  Lifetime (ns)  Quantum yield  \
# 0                    355.0             410.00       2.804262            NaN
# 1                    408.0             450.00       3.961965            NaN
# 2                    526.0             535.00       3.602954            NaN
# 3                    514.0             553.72       3.810000            NaN
# 4                    524.0             555.00       4.700000            NaN
# ...                    ...                ...            ...            ...
# 20231                358.0                NaN            NaN            NaN
# 20232                348.0                NaN            NaN            NaN
# 20233                344.0             460.00            NaN            NaN
# 20234                346.0                NaN            NaN            NaN
# 20235                344.0             473.00            NaN            NaN
#
#        log(e/mol-1 dm3 cm-1)  abs FWHM (cm-1)  emi FWHM (cm-1)  abs FWHM (nm)  \
# 0                        NaN              NaN              NaN            NaN
# 1                        NaN              NaN              NaN            NaN
# 2                        NaN              NaN              NaN            NaN
# 3                        NaN              NaN              NaN            NaN
# 4                        NaN              NaN              NaN           58.0
# ...                      ...              ...              ...            ...
# 20231                    NaN              NaN              NaN            NaN
# 20232                    NaN              NaN              NaN            NaN
# 20233                    NaN              NaN              NaN            NaN
# 20234                    NaN              NaN              NaN            NaN
# 20235                    NaN              NaN              NaN            NaN
#
#        emi FWHM (nm)  Molecular weight (g mol-1)  \
# 0                NaN                   187.15370
# 1               43.0                   186.14576
# 2                NaN                  1061.54348
# 3               67.4                   350.42028
# 4               50.0                   350.42028
# ...              ...                         ...
# 20231            NaN                   350.41992
# 20232            NaN                   364.44680
# 20233            NaN                   414.50668
# 20234            NaN                   414.50668
# 20235            NaN                   488.58856
#
#                                        Reference
# 0                  DOI: 10.1021/acs.jpcb.5b09905
# 1                  DOI: 10.1021/acs.jpcb.5b09905
# 2         https://doi.org/10.1002/smll.201901342
# 3      https://doi.org/10.1016/j.snb.2018.10.043
# 4      https://doi.org/10.1016/j.snb.2018.10.043
# ...                                          ...
# 20231                     DOI: 10.1021/ol9000679
# 20232                     DOI: 10.1021/ol9000679
# 20233                     DOI: 10.1021/ol9000679
# 20234                     DOI: 10.1021/ol9000679
# 20235                     DOI: 10.1021/ol9000679
#
# [20236 rows x 14 columns]

# %%
if same_test_set:
    prop_to_col = {'absPeak': 'Absorption max (nm)', 'emiPeak': 'Emission max (nm)', 'quantumYield': 'Quantum yield'}
    for p in optical_properties:
        empty_idx = joung_df[joung_df[prop_to_col[p]].isna()].index
        joung_df.drop(index=empty_idx, inplace=True)
joung_df
# Out:
#          Tag                                        Chromophore    Solvent  \
# 0          1                             N#Cc1cc2ccc(O)cc2oc1=O          O
# 1          2                          N#Cc1cc2ccc([O-])cc2oc1=O          O
# 2          3  CCCCCCCCCCCC#CC#CCCCCCCCCCN1C(=O)c2ccc3c4ccc5c...  ClC(Cl)Cl
# 3          4       [O-]c1c(-c2nc3ccccc3s2)cc2ccc3cccc4ccc1c2c34       CC#N
# 4          5       [O-]c1c(-c2nc3ccccc3s2)cc2ccc3cccc4ccc1c2c34    CS(C)=O
# ...      ...                                                ...        ...
# 20228  20229  N#Cc1c(N2CCCCC2)cc(-c2cccc3ccccc23)c2c1Cc1cccc...    C1CCOC1
# 20229  20230  N#Cc1c(N2CCCCC2)cc(-c2ccc3ccccc3c2)c2c1Cc1cccc...    C1CCOC1
# 20230  20231  N#Cc1c(N2CCCCC2)cc(-c2ccc3ccc4cccc5ccc2c3c45)c...    C1CCOC1
# 20233  20234  N#Cc1c(N2CCCCC2)cc(-c2cccc3ccccc23)c2c1C(=O)c1...    C1CCOC1
# 20235  20236  N#Cc1c(N2CCCCC2)cc(-c2ccc3ccc4cccc5ccc2c3c45)c...    C1CCOC1
#
#        Absorption max (nm)  Emission max (nm)  Lifetime (ns)  Quantum yield  \
# 0                    355.0             410.00       2.804262            NaN
# 1                    408.0             450.00       3.961965            NaN
# 2                    526.0             535.00       3.602954            NaN
# 3                    514.0             553.72       3.810000            NaN
# 4                    524.0             555.00       4.700000            NaN
# ...                    ...                ...            ...            ...
# 20228                358.0             451.00            NaN            NaN
# 20229                362.0             465.00            NaN            NaN
# 20230                344.0             481.00            NaN            NaN
# 20233                344.0             460.00            NaN            NaN
# 20235                344.0             473.00            NaN            NaN
#
#        log(e/mol-1 dm3 cm-1)  abs FWHM (cm-1)  emi FWHM (cm-1)  abs FWHM (nm)  \
# 0                        NaN              NaN              NaN            NaN
# 1                        NaN              NaN              NaN            NaN
# 2                        NaN              NaN              NaN            NaN
# 3                        NaN              NaN              NaN            NaN
# 4                        NaN              NaN              NaN           58.0
# ...                      ...              ...              ...            ...
# 20228                    NaN              NaN              NaN            NaN
# 20229                    NaN              NaN              NaN            NaN
# 20230                    NaN              NaN              NaN            NaN
# 20233                    NaN              NaN              NaN            NaN
# 20235                    NaN              NaN              NaN            NaN
#
#        emi FWHM (nm)  Molecular weight (g mol-1)  \
# 0                NaN                   187.15370
# 1               43.0                   186.14576
# 2                NaN                  1061.54348
# 3               67.4                   350.42028
# 4               50.0                   350.42028
# ...              ...                         ...
# 20228            NaN                   400.52356
# 20229            NaN                   400.52356
# 20230            NaN                   474.60544
# 20233            NaN                   414.50668
# 20235            NaN                   488.58856
#
#                                        Reference
# 0                  DOI: 10.1021/acs.jpcb.5b09905
# 1                  DOI: 10.1021/acs.jpcb.5b09905
# 2         https://doi.org/10.1002/smll.201901342
# 3      https://doi.org/10.1016/j.snb.2018.10.043
# 4      https://doi.org/10.1016/j.snb.2018.10.043
# ...                                          ...
# 20228                     DOI: 10.1021/ol9000679
# 20229                     DOI: 10.1021/ol9000679
# 20230                     DOI: 10.1021/ol9000679
# 20233                     DOI: 10.1021/ol9000679
# 20235                     DOI: 10.1021/ol9000679
#
# [16022 rows x 14 columns]

# %%
columns = {'Chromophore':'smiles','Solvent':'solvent', 'Absorption max (nm)':'abs_peakwavs_max', 
           'Emission max (nm)':'emi_peakwavs_max', 'abs FWHM (nm)':'abs_bandwidth',
           'emi FWHM (nm)':'emi_bandwidth', 'Quantum yield':'quantum_yield', 'Lifetime (ns)':'log_lifetime',
           'log(e/mol-1 dm3 cm-1)':'abs_molar_ext_coeff'}

joung_df.rename(columns=columns, 
                inplace=True)

joung_df.columns
# Out:
# Index(['Tag', 'smiles', 'solvent', 'abs_peakwavs_max', 'emi_peakwavs_max',
#        'log_lifetime', 'quantum_yield', 'abs_molar_ext_coeff',
#        'abs FWHM (cm-1)', 'emi FWHM (cm-1)', 'abs_bandwidth', 'emi_bandwidth',
#        'Molecular weight (g mol-1)', 'Reference'],
#       dtype='object')

# %%
# Drop columns of all other properties if creating same test set
if same_test_set:
    all_columns = list(joung_df.columns)
    dropped_columns = all_columns.copy()
    kept_columns = ['smiles', 'solvent']
    for c in all_columns[2:]: #excluding 'smiles' and 'solvent' columns
        for p in optical_properties:
            if c != columns[prop_to_col[p]]:
                continue
            else:
                dropped_columns.remove(c)
                kept_columns.append(c)
    dropped_columns = dropped_columns[3:] #excluding 'Tag', smiles', and 'solvent' columns
    joung_df.drop(axis=1, labels=dropped_columns, inplace=True)
joung_df
# Out:
#          Tag                                             smiles    solvent  \
# 0          1                             N#Cc1cc2ccc(O)cc2oc1=O          O
# 1          2                          N#Cc1cc2ccc([O-])cc2oc1=O          O
# 2          3  CCCCCCCCCCCC#CC#CCCCCCCCCCN1C(=O)c2ccc3c4ccc5c...  ClC(Cl)Cl
# 3          4       [O-]c1c(-c2nc3ccccc3s2)cc2ccc3cccc4ccc1c2c34       CC#N
# 4          5       [O-]c1c(-c2nc3ccccc3s2)cc2ccc3cccc4ccc1c2c34    CS(C)=O
# ...      ...                                                ...        ...
# 20228  20229  N#Cc1c(N2CCCCC2)cc(-c2cccc3ccccc23)c2c1Cc1cccc...    C1CCOC1
# 20229  20230  N#Cc1c(N2CCCCC2)cc(-c2ccc3ccccc3c2)c2c1Cc1cccc...    C1CCOC1
# 20230  20231  N#Cc1c(N2CCCCC2)cc(-c2ccc3ccc4cccc5ccc2c3c45)c...    C1CCOC1
# 20233  20234  N#Cc1c(N2CCCCC2)cc(-c2cccc3ccccc23)c2c1C(=O)c1...    C1CCOC1
# 20235  20236  N#Cc1c(N2CCCCC2)cc(-c2ccc3ccc4cccc5ccc2c3c45)c...    C1CCOC1
#
#        abs_peakwavs_max  emi_peakwavs_max
# 0                 355.0            410.00
# 1                 408.0            450.00
# 2                 526.0            535.00
# 3                 514.0            553.72
# 4                 524.0            555.00
# ...                 ...               ...
# 20228             358.0            451.00
# 20229             362.0            465.00
# 20230             344.0            481.00
# 20233             344.0            460.00
# 20235             344.0            473.00
#
# [16022 rows x 5 columns]

# %%
# Drop measurements where solvent == 'gas'
gas_idx = joung_df[joung_df['solvent']=='gas'].index
joung_df.drop(index=gas_idx, inplace=True)

# Drop measurements taken in solid state (original authors wrote file as chromophore == solvent for these cases)
ss_idx = joung_df[joung_df['smiles']==joung_df['solvent']].index
joung_df.drop(index=ss_idx, inplace=True)

# Create df with target properties and drop NaNs
if same_test_set:
    col_names = kept_columns
else:
    col_names = list(columns.values())
joung_df = joung_df[col_names].copy()
joung_df.dropna(inplace=True)
joung_df['source'] = 'deep4chem'

df = joung_df
prop_col_names = col_names[2:]
for col_name in prop_col_names:
    df = df.loc[df[col_name]!='-'].copy()
    df[col_name] = df[col_name].apply(lambda x: float(x))


# # Filtering

# ### Remove Molecules that Cannot be Sanitized by RDKit

def sanitize_smiles(smiles):
    try:
        smiles = Chem.MolToSmiles(Chem.MolFromSmiles(smiles))
    except:
        smiles = np.nan
    return smiles

df['smiles'] = df['smiles'].apply(lambda x: sanitize_smiles(x))
df['solvent'] = df['solvent'].apply(lambda x: sanitize_smiles(x))
df.dropna(inplace=True)


# ### Remove Clusters (SMILES containing ".")

cluster_idx = df[df['smiles'].str.contains('\.')].index
#print('Removing {} rows'.format(len(cluster_idx)))
df.drop(index=cluster_idx, inplace=True)

# %%
df
# Out:
#                                                   smiles    solvent  \
# 0                                 N#Cc1cc2ccc(O)cc2oc1=O          O
# 1                              N#Cc1cc2ccc([O-])cc2oc1=O          O
# 2      CCCCCCCCCCCC#CC#CCCCCCCCCCN1C(=O)c2ccc3c4ccc5c...  ClC(Cl)Cl
# 3           [O-]c1c(-c2nc3ccccc3s2)cc2ccc3cccc4ccc1c2c34       CC#N
# 4           [O-]c1c(-c2nc3ccccc3s2)cc2ccc3cccc4ccc1c2c34    CS(C)=O
# ...                                                  ...        ...
# 20228  N#Cc1c(N2CCCCC2)cc(-c2cccc3ccccc23)c2c1Cc1cccc...    C1CCOC1
# 20229  N#Cc1c(N2CCCCC2)cc(-c2ccc3ccccc3c2)c2c1Cc1cccc...    C1CCOC1
# 20230  N#Cc1c(N2CCCCC2)cc(-c2ccc3ccc4cccc5ccc2c3c45)c...    C1CCOC1
# 20233  N#Cc1c(N2CCCCC2)cc(-c2cccc3ccccc23)c2c1C(=O)c1...    C1CCOC1
# 20235  N#Cc1c(N2CCCCC2)cc(-c2ccc3ccc4cccc5ccc2c3c45)c...    C1CCOC1
#
#        abs_peakwavs_max  emi_peakwavs_max     source
# 0                 355.0            410.00  deep4chem
# 1                 408.0            450.00  deep4chem
# 2                 526.0            535.00  deep4chem
# 3                 514.0            553.72  deep4chem
# 4                 524.0            555.00  deep4chem
# ...                 ...               ...        ...
# 20228             358.0            451.00  deep4chem
# 20229             362.0            465.00  deep4chem
# 20230             344.0            481.00  deep4chem
# 20233             344.0            460.00  deep4chem
# 20235             344.0            473.00  deep4chem
#
# [15644 rows x 5 columns]

# %%
if same_test_set:
    file_name = 'data_same_test_set_'
else:
    file_name = ''
for i, property in enumerate(optical_properties):
    file_name += property
    if len(optical_properties) > 1 and i < (len(optical_properties) - 1):
        file_name += '_'
file_name += '.csv'
print(file_name)

x = col_names + ['source']
print(x)
# Out:
# data_same_test_set_absPeak_emiPeak.csv
# ['smiles', 'solvent', 'abs_peakwavs_max', 'emi_peakwavs_max', 'source']

# %%
df[x].to_csv(f'{data_processed_dir}/{file_name}', 
                                                        index=False)

# %%
import itertools

# %%
combos_x = []
combos_file_name = []
for i in range(1, len(col_names[2:])+1):
    combos_x.extend(list((itertools.combinations(col_names[2:], i))))
    combos_file_name.extend(list((itertools.combinations(optical_properties, i))))
print(combos_x)
print(combos_file_name)
# Out:
# [('abs_peakwavs_max',), ('emi_peakwavs_max',), ('abs_peakwavs_max', 'emi_peakwavs_max')]
# [('absPeak',), ('emiPeak',), ('absPeak', 'emiPeak')]

# %%
if same_test_set:
    file_name = 'data_same_test_set_'
else:
    file_name = ''
for combo in combos_file_name:
    for i in combo:
        file_name += i + '_'
#     file_name += '.csv'
    print(file_name)
# Out:
# data_same_test_set_absPeak_
# data_same_test_set_absPeak_emiPeak_
# data_same_test_set_absPeak_emiPeak_absPeak_emiPeak_

# %%
if same_test_set:
    file_name = 'data_same_test_set_'
else:
    file_name = ''
for i, property in enumerate(optical_properties):
    file_name += property
    if len(optical_properties) > 1 and i < (len(optical_properties) - 1):
        file_name += '_'
file_name += '.csv'

x = col_names + ['source']
# df[x].to_csv(f'{data_processed_dir}/{file_name}', 
#                                                         index=False)
x
# Out:
# ['smiles', 'solvent', 'abs_peakwavs_max', 'emi_peakwavs_max', 'source']

# %%
x_1 = x.copy()
x_1 = x_1[:3] + x_1[3+1 :]
x_1

x_2 = x.copy()
x_2 = x_2[:2] + x_2[2+1 :]
x_2
# Out:
# ['smiles', 'solvent', 'emi_peakwavs_max', 'source']

# %%
file_name
# Out:
# 'data_same_test_set_absPeak_emiPeak.csv'
